# %%
#task1 23l-2594
#1. Write a Python program that initializes a list with several integers. Ask the
#user to guess the sum of all numbers in the list. Use an if-else statement to
#check the user&#39;s guess and print whether they are correct or incorrect.
integer=[1,2,3,4,5]
print("guess the sum of the integer")
guess=int(input())
if guess==sum(integer):
  print("correct sum")
else:
  print("incorrect sum ")

#task2 Create a dictionary with names as keys and email addresses as values. Write
#a Python program that asks the user to enter a name, and then checks if the
#name exists in the dictionary. If it exists, print the associated email address;
#otherwise, print &quot;Name not found.&quot;

dictionary={"hira":"hirakhalid@gmail.com",
            "urwa":"urwakhalid@gmail.com",
            "fryal":"fryalzahra@gmail.com"
}

name=input("enter name")
if name in dictionary:
  print(dictionary[name])
else:
  print("name not found")
#3. Ask the user to input three numbers. Use if-elif-else statements to determine
#and print the largest number among the three.
number1=int(input("enter the number1"))
number2=int(input("enter the number1"))
number3=int(input("enter the number1"))
if number1>number2 and number1>number3:
  print("the largest number is")
  print(number1)
elif number2>number1 and number2>number3:
  print("the largest number is")
  print(number2)
else:
  print("the largest number is")
  print(number3)


 # 4-Write a program that asks the user for a numerical grade (0-100). Based on
#the grade, use if-elif-else statements to print the corresponding letter grade
#(A, B, C, D, F, where A is 90 and above, B is 80-89, etc.).
grade=int(input("enter the marks"))
if grade>=90:
  print("the grade is A")
elif grade>=80:
  print("the grade is B")
elif grade>=70:
  print("the grade is C")
elif grade>=60:
  print("the grade is D")
else:
 print("the grade is F")

#5. Create a Python program that converts temperatures from Fahrenheit to
#Celsius or Celsius to Fahrenheit depending on user input. Ask the user first
#for the conversion direction, and then for the temperature to convert.
temperature=float(input("enter the temperature"))
variable=input("enter f for farenhiet to celsuis and enter c for celsuis to farenhiet")
if variable=='f':
  celsuis=(temperature-32)*5/9
elif variable=='c':
  farenheit=(temperature*9/5)+32
else:
  print("invalid conversion type")

  #task 6
  #Write a Python program that asks the user to input a starting number for a
#countdown. Use a while loop to print each number in the countdown
#sequence until it reaches zero.
  number=int(input("enter the number"))
  while number>0:
    print(number)
    number=number-1

    #task7 7. Initialize a dictionary with string keys and integer values. Write a Python
#program that asks the user for a key and an integer to add to the value
#associated with that key. Update the dictionary and print the new value.
dictionary={"a":1,"b":2,"c":3,"d":4}
key=input("enter the key(a,b,c,d) for increment")
temp=int(input("enter the integer for add"))
if key in dictionary:
  dictionary[key]=dictionary[key]+temp
  print(f"updated value for{key}is:{dictionary[key]}")
else:
  print("key not found")

 # 8. Write a Python program that initializes a list with several integers. Use a loop
#and if-elif-else structure to separate these integers into two new lists: one for
#even numbers and another for odd numbers. Print both lists.
list=[1,2,3,4,45.5]
even_numbers=[]
odd_numbers=[]
for temp in list:
  if temp%2==0:
    even_numbers.append(temp)
  else
  odd_numbers.append(temp)
  print("the even numbers list is")
  print(even_numbers)
  print("the odd numbers list is")
  print(odd_numbers)
  #task 9
 # Write a Python program that asks the user to input a number. Use a loop and
#if-elif-else structure to determine if the number is a prime number (a prime
#number is a number that has no divisors other than 1 and itself). Print &quot;Prime&quot;
#if the number is prime, otherwise print &quot;Not prime&quot;.
  number=int(input("enter the number"))
  if number<=1:
    print("the number is not prime")
  elif(number==2 or number==3)
   print("the number is prime")
  else:
    isprime=True
    for n in range(2,num):
      if(number%n==0):
        isprime=False
        break
        if(isprime):
          print("the number is prime")
      else:
        print("the number is not prime")

        #task 10
       # Write a Python program that initializes a list with integers. Ask the user for a multiplier. Use a loop to multiply each element of the list by the multiplier and print the new list.
        list=[1,2,3,4,5]
        print("original list",list)
        multipler=int(input("enter a number"))
        multiplied-list-[]
        for num in list:
          multiplied_list.append(multiplier*num)
          print("new list",multiplied_list)
# Out:
# guess the sum of the integer
# 34
# incorrect sum
# enter namehira
# hirakhalid@gmail.com
